# %% [markdown]
# ## Easemytrip - Web Scrapping
# #### date - 21/june/2022

# %%
# let's import all required libraries
import selenium
from selenium import webdriver
import pandas as pd
import time
import warnings
warnings.filterwarnings('ignore')
from bs4 import BeautifulSoup
import requests

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException,ElementNotInteractableException

# %%
driver=webdriver.Chrome(r"/Users/vikram/Downloads/chromedriver")
time.sleep(2)
url="https://www.easemytrip.com/"
driver.get(url)#enter to olx.in through chrome browser

# %%
driver.execute_script("window.scrollBy(0,800)")

# %%
urls=[]
for i in driver.find_elements_by_xpath("//a[@class='srch_btn']"):
    urls.append(i.get_attribute("href"))

# %%
len(urls)
# Out:
# 20

# %%
airline = [] 
dep_time = []
arrival_time = []
source = []
destination = []
stops= [] 
duration= [] 
price= []

# %%
# date = 21 june 2022
for i in urls:
    driver.get(i)#loading the url on web driver
    time.sleep(4) # giving the webpage 4 seconds to load
    
    name=driver.find_elements_by_xpath("//span[@class='txt-r4 ng-binding']")
    for i in name:
        airline.append(i.text)
        
    dep=driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-4 top5 ']//span[1]")
    for i in dep:
        dep_time.append(i.text) 
        
    arv = driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-3 top5']//span[1]")
    for i in arv:
        arrival_time.append(i.text)
    
    sou=driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-4 top5 ']//span[2]")
    for i in sou:
        source.append(i.text)
        
    des = driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-3 top5']//span[2]")
    for i in des:
        destination.append(i.text)
     
    tm = driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-5 non-st']//span[1]")
    for i in tm:
        duration.append(i.text)
        
    sts = driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-5 non-st']//span[2]")
    for i in sts:
        stops.append(i.text)

    rate = driver.find_elements_by_xpath("//div[@class='col-md-8 col-sm-8 col-xs-9 txt-r6-n exPrc ng-binding']")
    for i in rate:
        price.append(i.text)

# %%
#DATA FRAMEING
Flights=pd.DataFrame({})
Flights['Airline'] = airline
Flights['Source'] = source
Flights['Destination'] = destination
Flights['Depature Time'] = dep_time
Flights['Arrival Time'] = arrival_time
Flights['Stops'] = stops
Flights['Duration'] = duration[:1352]
Flights['Price'] = price

Flights # for 21 June
# Out:
#        Airline  Source Destination Depature Time Arrival Time     Stops  \
# 0      AirAsia   Delhi      Mumbai         04:25        06:35  non-stop
# 1       Indigo   Delhi      Mumbai         06:30        08:35  non-stop
# 2       Indigo   Delhi      Mumbai         02:00        04:10  non-stop
# 3     GO FIRST   Delhi      Mumbai         14:00        16:10  non-stop
# 4       Indigo   Delhi      Mumbai         15:25        17:35  non-stop
# ...        ...     ...         ...           ...          ...       ...
# 1347   Vistara  Mumbai   Bangalore         11:55        18:50    1-stop
# 1348   Vistara  Mumbai   Bangalore         10:25        18:50    1-stop
# 1349   Vistara  Mumbai   Bangalore         07:30        16:50    1-stop
# 1350   Vistara  Mumbai   Bangalore         08:45        16:50    1-stop
# 1351   Vistara  Mumbai   Bangalore         08:45        18:50    1-stop
#
#      Duration   Price
# 0     02h 10m   8,579
# 1     02h 05m   8,579
# 2     02h 10m   8,579
# ...

# %%
date = [] # adding date to dataframe

for i in range(1352):
    date.append("21/06/2022")
date
# Out:
# ['21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
#  '21/06/2022',
# ...

# %%
Flights['Date'] = date
Flights
# Out:
#        Airline  Source Destination Depature Time Arrival Time     Stops  \
# 0      AirAsia   Delhi      Mumbai         04:25        06:35  non-stop
# 1       Indigo   Delhi      Mumbai         06:30        08:35  non-stop
# 2       Indigo   Delhi      Mumbai         02:00        04:10  non-stop
# 3     GO FIRST   Delhi      Mumbai         14:00        16:10  non-stop
# 4       Indigo   Delhi      Mumbai         15:25        17:35  non-stop
# ...        ...     ...         ...           ...          ...       ...
# 1347   Vistara  Mumbai   Bangalore         11:55        18:50    1-stop
# 1348   Vistara  Mumbai   Bangalore         10:25        18:50    1-stop
# 1349   Vistara  Mumbai   Bangalore         07:30        16:50    1-stop
# 1350   Vistara  Mumbai   Bangalore         08:45        16:50    1-stop
# 1351   Vistara  Mumbai   Bangalore         08:45        18:50    1-stop
#
#      Duration   Price        Date
# 0     02h 10m   8,579  21/06/2022
# ...

# %%
driver.close() #closing driver to open new for another date

# %% [markdown]
# ## again running same process but scrapping info of date one month later to get rate difference and know more about it

# %%
driver=webdriver.Chrome(r"/Users/vikram/Downloads/chromedriver")
time.sleep(2)
url1="https://www.easemytrip.com/"
driver.get(url1)
time.sleep(3)

# %%
driver.execute_script("window.scrollBy(0,800)")
time.sleep(2)
urls1=[]
for i in driver.find_elements_by_xpath("//a[@class='srch_btn']"):
    urls1.append(i.get_attribute("href"))

# %%
len(urls1)
# Out:
# 20

# %%
#after 1 month = 21-07-2022
airline1 = [] 
dep_time1 = []
arrival_time1 = []
source1 = []
destination1 = []
stops1= [] 
duration1= [] 
price1= []

# %%
# date = 21 july 2022
for i in urls:
    driver.get(i)#loading the url on web driver
    time.sleep(4) # giving the webpage 4 seconds to load
    
    driver.find_element_by_xpath("//div[@class='inp-b4n']").click() #opening calendar
    time.sleep(5)
    try:
        driver.find_element_by_id("frth_4_21/07/2022").click() #selecting date = 21-07-2022
    except ElementClickInterceptedException:
        driver.close()
    time.sleep(4)
    
    
    name=driver.find_elements_by_xpath("//span[@class='txt-r4 ng-binding']")
    for i in name:
        airline1.append(i.text)
        
    dep=driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-4 top5 ']//span[1]")
    for i in dep:
        dep_time1.append(i.text) 
        
    arv = driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-3 top5']//span[1]")
    for i in arv:
        arrival_time1.append(i.text)
    
    sou=driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-4 top5 ']//span[2]")
    for i in sou:
        source1.append(i.text)
        
    des = driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-3 top5']//span[2]")
    for i in des:
        destination1.append(i.text)
     
    tm = driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-5 non-st']//span[1]")
    for i in tm:
        duration1.append(i.text)
        
    sts = driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-5 non-st']//span[2]")
    for i in sts:
        stops1.append(i.text)

    rate = driver.find_elements_by_xpath("//div[@class='col-md-8 col-sm-8 col-xs-9 txt-r6-n exPrc ng-binding']")
    for i in rate:
        price1.append(i.text)

# %%
#DATA FRAMEING
Flights1=pd.DataFrame({})
Flights1['Airline'] = airline1
Flights1['Source'] = source1
Flights1['Destination'] = destination1
Flights1['Depature Time'] = dep_time1
Flights1['Arrival Time'] = arrival_time1
Flights1['Stops'] = stops1
Flights1['Duration'] = duration1[:1633]
Flights1['Price'] = price1

Flights1 # for 21 July
# Out:
#         Airline  Source Destination Depature Time Arrival Time    Stops  \
# 0       AirAsia   Delhi      Mumbai         06:05        21:20  2+-stop
# 1       AirAsia   Delhi      Mumbai         12:50        19:15   1-stop
# 2       AirAsia   Delhi      Mumbai         07:25        14:05   1-stop
# 3       AirAsia   Delhi      Mumbai         10:40        19:15   1-stop
# 4       AirAsia   Delhi      Mumbai         21:40        07:15   1-stop
# ...         ...     ...         ...           ...          ...      ...
# 1628  Air India  Mumbai   Bangalore         11:15        12:30  2+-stop
# 1629  Air India  Mumbai   Bangalore         11:15        16:15  2+-stop
# 1630  Air India  Mumbai   Bangalore         18:50        20:15  2+-stop
# 1631  Air India  Mumbai   Bangalore         18:50        16:15  2+-stop
# 1632     Indigo  Mumbai   Bangalore         11:25        15:50   1-stop
#
#      Duration   Price
# 0     15h 15m   5,532
# 1     06h 25m   5,952
# 2     06h 40m   5,952
# ...

# %%
date1 = []

for i in range(1633):
    date1.append("21/07/2022")
date1
# Out:
# ['21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
#  '21/07/2022',
# ...

# %%
Flights1['Date'] = date1
Flights1
# Out:
#         Airline  Source Destination Depature Time Arrival Time    Stops  \
# 0       AirAsia   Delhi      Mumbai         06:05        21:20  2+-stop
# 1       AirAsia   Delhi      Mumbai         12:50        19:15   1-stop
# 2       AirAsia   Delhi      Mumbai         07:25        14:05   1-stop
# 3       AirAsia   Delhi      Mumbai         10:40        19:15   1-stop
# 4       AirAsia   Delhi      Mumbai         21:40        07:15   1-stop
# ...         ...     ...         ...           ...          ...      ...
# 1628  Air India  Mumbai   Bangalore         11:15        12:30  2+-stop
# 1629  Air India  Mumbai   Bangalore         11:15        16:15  2+-stop
# 1630  Air India  Mumbai   Bangalore         18:50        20:15  2+-stop
# 1631  Air India  Mumbai   Bangalore         18:50        16:15  2+-stop
# 1632     Indigo  Mumbai   Bangalore         11:25        15:50   1-stop
#
#      Duration   Price        Date
# 0     15h 15m   5,532  21/07/2022
# ...

# %%
driver=webdriver.Chrome(r"/Users/vikram/Downloads/chromedriver")
time.sleep(2)
url1="https://www.easemytrip.com/"
driver.get(url1)
time.sleep(3)

# %%
driver.execute_script("window.scrollBy(0,800)")
time.sleep(2)
urls2=[]
for i in driver.find_elements_by_xpath("//a[@class='srch_btn']"):
    urls2.append(i.get_attribute("href"))

# %%
len(urls2)
# Out:
# 20

# %%
#after 16 days  = 08-07-2022
airline2 = [] 
dep_time2 = []
arrival_time2 = []
source2 = []
destination2 = []
stops2= [] 
duration2= [] 
price2= []

# %%
# date = 08 july 2022
for i in urls2:
    driver.get(i)#loading the url on web driver
    time.sleep(4) # giving the webpage 4 seconds to load
    
    driver.find_element_by_xpath("//div[@class='inp-b4n']").click() #opening calendar
    time.sleep(5)
    try:
        driver.find_element_by_id("snd_5_08/07/2022").click() #selecting date = 08-07-2022
    except ElementClickInterceptedException:
        driver.close()
    time.sleep(4)
    
    
    name=driver.find_elements_by_xpath("//span[@class='txt-r4 ng-binding']")
    for i in name:
        airline2.append(i.text)
        
    dep=driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-4 top5 ']//span[1]")
    for i in dep:
        dep_time2.append(i.text) 
        
    arv = driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-3 top5']//span[1]")
    for i in arv:
        arrival_time2.append(i.text)
    
    sou=driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-4 top5 ']//span[2]")
    for i in sou:
        source2.append(i.text)
        
    des = driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-3 top5']//span[2]")
    for i in des:
        destination2.append(i.text)
     
    tm = driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-5 non-st']//span[1]")
    for i in tm:
        duration2.append(i.text)
        
    sts = driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-5 non-st']//span[2]")
    for i in sts:
        stops2.append(i.text)

    rate = driver.find_elements_by_xpath("//div[@class='col-md-8 col-sm-8 col-xs-9 txt-r6-n exPrc ng-binding']")
    for i in rate:
        price2.append(i.text)

# %%
#DATA FRAMEING
Flights2=pd.DataFrame({})
Flights2['Airline'] = airline2
Flights2['Source'] = source2
Flights2['Destination'] = destination2
Flights2['Depature Time'] = dep_time2
Flights2['Arrival Time'] = arrival_time2
Flights2['Stops'] = stops2
Flights2['Duration'] = duration2[:1551]
Flights2['Price'] = price2

Flights1 # for 08 July
# Out:
#         Airline  Source Destination Depature Time Arrival Time     Stops  \
# 0       AirAsia   Delhi      Mumbai         20:00        07:05    1-stop
# 1       Vistara   Delhi      Mumbai         05:55        07:55  non-stop
# 2        Indigo   Delhi      Mumbai         02:10        04:10  non-stop
# 3        Indigo   Delhi      Mumbai         11:55        13:55  non-stop
# 4        Indigo   Delhi      Mumbai         06:30        08:35  non-stop
# ...         ...     ...         ...           ...          ...       ...
# 1546    Vistara  Mumbai   Bangalore         06:45        17:05   2+-stop
# 1547    Vistara  Mumbai   Bangalore         06:45        18:50   2+-stop
# 1548  Air India  Mumbai   Bangalore         18:50        20:15   2+-stop
# 1549  Air India  Mumbai   Bangalore         18:50        12:30   2+-stop
# 1550  Air India  Mumbai   Bangalore         18:50        16:15   2+-stop
#
#      Duration  Price
# 0     11h 05m
# 1     02h 00m  7,110
# 2     02h 00m  7,109
# ...

# %%
date2 = []

for i in range(1551):
    date2.append("08/07/2022")
date2
# Out:
# ['08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
#  '08/07/2022',
# ...

# %%
Flights2['Date'] = date2
Flights2
# Out:
#         Airline  Source Destination Depature Time Arrival Time     Stops  \
# 0       AirAsia   Delhi      Mumbai         20:00        07:05    1-stop
# 1       Vistara   Delhi      Mumbai         05:55        07:55  non-stop
# 2        Indigo   Delhi      Mumbai         02:10        04:10  non-stop
# 3        Indigo   Delhi      Mumbai         11:55        13:55  non-stop
# 4        Indigo   Delhi      Mumbai         06:30        08:35  non-stop
# ...         ...     ...         ...           ...          ...       ...
# 1546    Vistara  Mumbai   Bangalore         06:45        17:05   2+-stop
# 1547    Vistara  Mumbai   Bangalore         06:45        18:50   2+-stop
# 1548  Air India  Mumbai   Bangalore         18:50        20:15   2+-stop
# 1549  Air India  Mumbai   Bangalore         18:50        12:30   2+-stop
# 1550  Air India  Mumbai   Bangalore         18:50        16:15   2+-stop
#
#      Duration  Price        Date
# 0     11h 05m         08/07/2022
# ...

# %%
# CONCATING TWO DATAFRAMES TO FORM ONE
Frames = [Flights,Flights1,Flights2 ]

Flight_data = pd.concat(Frames)

# %%
Flight_data.to_csv("Flight_scrapping1.csv") # converting to csv for importing
